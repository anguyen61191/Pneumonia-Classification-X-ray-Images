# %%
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from keras.callbacks import ReduceLROnPlateau
import cv2
import os
import numpy as np



from numpy.random import seed
seed(42)

# %%
labels = ['PNEUMONIA', 'NORMAL']
img_size = 150
def get_training_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# %%
train = get_training_data('/content/drive/MyDrive/chest_xray/train')
test = get_training_data('/content/drive/MyDrive/chest_xray/test')
val = get_training_data('/content/drive/MyDrive/chest_xray/val')
# Out:
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   from ipykernel import kernelapp as app
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
l = []
for i in train:
    if(i[1] == 0):
        l.append("Pneumonia")
    else:
        l.append("Normal")
sns.set_style('darkgrid')
sns.countplot(l)

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[0][0], cmap='gray')
plt.title(labels[train[0][1]])

plt.figure(figsize = (5,5))
plt.imshow(train[-1][0], cmap='gray')
plt.title(labels[train[-1][1]]);

# %%
x_train = []
y_train = []

x_val = []
y_val = []

x_test = []
y_test = []

for feature, label in train:
    x_train.append(feature)
    y_train.append(label)

for feature, label in test:
    x_test.append(feature)
    y_test.append(label)
    
for feature, label in val:
    x_val.append(feature)
    y_val.append(label)

# %%
#Normalize the data
x_train = np.array(x_train) / 253
x_val = np.array(x_val) / 253
x_test = np.array(x_test) / 253

# %%
# #make array
# x_train = np.array(x_train)
# x_val = np.array(x_val) 
# x_test = np.array(x_test)

# %%
# resize data for deep learning 
x_train = x_train.reshape(-1, img_size, img_size, 1)
y_train = np.array(y_train)

x_val = x_val.reshape(-1, img_size, img_size, 1)
y_val = np.array(y_val)

x_test = x_test.reshape(-1, img_size, img_size, 1)
y_test = np.array(y_test)

# %%
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range = 30,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.2, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip = True,  # randomly flip images
        vertical_flip=False)  # randomly flip images


datagen.fit(x_train)

# %%
import tensorflow as tf

# %%
model = Sequential()
model.add(Conv2D(32 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu' , input_shape = (150,150,1)))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
model.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.1))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
model.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
model.add(Conv2D(128 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.2))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
model.add(Conv2D(256 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.2))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
model.add(Flatten())
model.add(Dense(units = 128 , activation = 'relu'))
model.add(Dropout(0.2))
model.add(Dense(units = 1 , activation = 'sigmoid'))
model.compile(optimizer = "rmsprop" , loss = 'binary_crossentropy' , metrics = ['accuracy', tf.keras.metrics.Recall()])
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 150, 150, 32)      320
#
#  batch_normalization_5 (Batc  (None, 150, 150, 32)     128
#  hNormalization)
#
#  max_pooling2d_9 (MaxPooling  (None, 75, 75, 32)       0
#  2D)
#
#  conv2d_11 (Conv2D)          (None, 75, 75, 64)        18496
#
#  dropout_4 (Dropout)         (None, 75, 75, 64)        0
#
#  batch_normalization_6 (Batc  (None, 75, 75, 64)       256
#  hNormalization)
#
#  max_pooling2d_10 (MaxPoolin  (None, 38, 38, 64)       0
#  g2D)
#
#  conv2d_12 (Conv2D)          (None, 38, 38, 64)        36928
#
#  batch_normalization_7 (Batc  (None, 38, 38, 64)       256
#  hNormalization)
#
#  max_pooling2d_11 (MaxPoolin  (None, 19, 19, 64)       0
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 19, 19, 128)       73856
#
#  dropout_5 (Dropout)         (None, 19, 19, 128)       0
#
#  batch_normalization_8 (Batc  (None, 19, 19, 128)      512
#  hNormalization)
#
#  max_pooling2d_12 (MaxPoolin  (None, 10, 10, 128)      0
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 10, 10, 256)       295168
#
#  dropout_6 (Dropout)         (None, 10, 10, 256)       0
#
#  batch_normalization_9 (Batc  (None, 10, 10, 256)      1024
#  hNormalization)
#
#  max_pooling2d_13 (MaxPoolin  (None, 5, 5, 256)        0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 6400)              0
#
#  dense_4 (Dense)             (None, 128)               819328
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 1,246,401
# Trainable params: 1,245,313
# Non-trainable params: 1,088
# _________________________________________________________________

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience = 2, verbose=1,factor=0.3, min_lr=0.000001)

# %%
history = model.fit(datagen.flow(x_train,y_train, batch_size = 32) ,epochs = 12 , validation_data = datagen.flow(x_val, y_val) ,callbacks = [learning_rate_reduction])
# Out:
# Epoch 1/12
# 163/163 [==============================] - 305s 2s/step - loss: 0.6229 - accuracy: 0.8374 - recall: 0.7136 - val_loss: 25.0281 - val_accuracy: 0.5000 - val_recall: 0.0000e+00 - lr: 0.0010
# Epoch 2/12
# 163/163 [==============================] - 297s 2s/step - loss: 0.2943 - accuracy: 0.8949 - recall: 0.7972 - val_loss: 29.7301 - val_accuracy: 0.5000 - val_recall: 0.0000e+00 - lr: 0.0010
# Epoch 3/12
# 163/163 [==============================] - ETA: 0s - loss: 0.2335 - accuracy: 0.9145 - recall: 0.8434
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 163/163 [==============================] - 296s 2s/step - loss: 0.2335 - accuracy: 0.9145 - recall: 0.8434 - val_loss: 47.2972 - val_accuracy: 0.5000 - val_recall: 0.0000e+00 - lr: 0.0010
# Epoch 4/12
# 163/163 [==============================] - 293s 2s/step - loss: 0.1699 - accuracy: 0.9450 - recall: 0.9038 - val_loss: 43.6660 - val_accuracy: 0.5000 - val_recall: 0.0000e+00 - lr: 3.0000e-04
# Epoch 5/12
# 163/163 [==============================] - 293s 2s/step - loss: 0.1514 - accuracy: 0.9482 - recall: 0.9001 - val_loss: 0.6204 - val_accuracy: 0.6875 - val_recall: 0.3750 - lr: 3.0000e-04
# Epoch 6/12
# 163/163 [==============================] - 293s 2s/step - loss: 0.1377 - accuracy: 0.9525 - recall: 0.9128 - val_loss: 68.8798 - val_accuracy: 0.5000 - val_recall: 0.0000e+00 - lr: 3.0000e-04
# Epoch 7/12
# 163/163 [==============================] - ETA: 0s - loss: 0.1254 - accuracy: 0.9563 - recall: 0.9187
# Epoch 7: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 163/163 [==============================] - 294s 2s/step - loss: 0.1254 - accuracy: 0.9563 - recall: 0.9187 - val_loss: 1.2494 - val_accuracy: 0.5625 - val_recall: 0.8750 - lr: 3.0000e-04
# Epoch 8/12
# 163/163 [==============================] - 293s 2s/step - loss: 0.1134 - accuracy: 0.9632 - recall: 0.9284 - val_loss: 9.2275 - val_accuracy: 0.5000 - val_recall: 0.0000e+00 - lr: 9.0000e-05
# Epoch 9/12
# 163/163 [==============================] - ETA: 0s - loss: 0.1088 - accuracy: 0.9645 - recall: 0.9329
# Epoch 9: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 163/163 [==============================] - 292s 2s/step - loss: 0.1088 - accuracy: 0.9645 - recall: 0.9329 - val_loss: 5.6874 - val_accuracy: 0.5625 - val_recall: 0.1250 - lr: 9.0000e-05
# Epoch 10/12
# 163/163 [==============================] - 293s 2s/step - loss: 0.1058 - accuracy: 0.9664 - recall: 0.9344 - val_loss: 2.4836 - val_accuracy: 0.6250 - val_recall: 0.2500 - lr: 2.7000e-05
# Epoch 11/12
# 163/163 [==============================] - ETA: 0s - loss: 0.0960 - accuracy: 0.9676 - recall: 0.9344
# Epoch 11: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 163/163 [==============================] - 293s 2s/step - loss: 0.0960 - accuracy: 0.9676 - recall: 0.9344 - val_loss: 2.0712 - val_accuracy: 0.5625 - val_recall: 0.1250 - lr: 2.7000e-05
# Epoch 12/12
# 163/163 [==============================] - 293s 2s/step - loss: 0.1028 - accuracy: 0.9676 - recall: 0.9389 - val_loss: 0.7848 - val_accuracy: 0.5625 - val_recall: 0.1250 - lr: 8.1000e-06

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 150, 150, 32)      320
#
#  batch_normalization (BatchN  (None, 150, 150, 32)     128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 75, 75, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 75, 75, 64)        18496
#
#  dropout (Dropout)           (None, 75, 75, 64)        0
#
#  batch_normalization_1 (Batc  (None, 75, 75, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 38, 38, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 38, 38, 64)        36928
#
#  batch_normalization_2 (Batc  (None, 38, 38, 64)       256
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 19, 19, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 19, 19, 128)       73856
#
#  dropout_1 (Dropout)         (None, 19, 19, 128)       0
#
#  batch_normalization_3 (Batc  (None, 19, 19, 128)      512
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 10, 10, 128)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 10, 10, 256)       295168
#
#  dropout_2 (Dropout)         (None, 10, 10, 256)       0
#
#  batch_normalization_4 (Batc  (None, 10, 10, 256)      1024
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 5, 5, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 6400)              0
#
#  dense (Dense)               (None, 128)               819328
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 1,246,401
# Trainable params: 1,245,313
# Non-trainable params: 1,088
# _________________________________________________________________

# %%
print("Loss of the model is - " , model.evaluate(x_test,y_test)[0])
print("Accuracy of the model is - " , model.evaluate(x_test,y_test)[1]*100 , "%")
# Out:
# 20/20 [==============================] - 8s 359ms/step - loss: 0.2901 - accuracy: 0.9103 - recall: 0.8333
# Loss of the model is -  0.2900678813457489
# 20/20 [==============================] - 7s 359ms/step - loss: 0.2901 - accuracy: 0.9103 - recall: 0.8333
# Accuracy of the model is -  91.02563858032227 %

# %%
from sklearn.metrics import plot_confusion_matrix, accuracy_score, confusion_matrix, plot_roc_curve, \
make_scorer, recall_score, precision_score, f1_score

# %%
epochs = [i for i in range(12)]
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
fig.set_size_inches(20,10)

ax[0].plot(epochs , train_acc , 'go-' , label = 'Training Accuracy')
ax[0].plot(epochs , val_acc , 'ro-' , label = 'Validation Accuracy')
ax[0].set_title('Training & Validation Accuracy')
ax[0].legend()
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")

ax[1].plot(epochs , train_loss , 'g-o' , label = 'Training Loss')
ax[1].plot(epochs , val_loss , 'r-o' , label = 'Validation Loss')
ax[1].set_title('Training and Validation Loss')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Training & Validation Loss")
plt.show()

# %%
predictions = model.predict(x_test)
predictions = predictions.reshape(1,-1)[0]
predictions[:15]
# Out:
# array([3.90617430e-01, 5.15002512e-08, 1.80214643e-04, 9.93763578e-12,
#        8.44563221e-12, 1.53944790e-02, 1.66933102e-18, 1.05946392e-01,
#        1.08715892e-03, 6.78926706e-04, 3.13111232e-05, 1.55239105e-02,
#        1.71683894e-07, 7.66032934e-03, 1.68251991e-03], dtype=float32)

# %%
# print(classification_report(y_test, predictions, target_names = ['Pneumonia (Class 0)','Normal (Class 1)']))

# %%
# cm = confusion_matrix(y_test,predictions)
# cm

# %%
cm = pd.DataFrame(cm , index = ['0','1'] , columns = ['0','1'])

# %%
plt.figure(figsize = (10,10))
sns.heatmap(cm,cmap= "Blues", linecolor = 'black' , linewidth = 1 , annot = True, fmt='',xticklabels = labels,yticklabels = labels)

# %%
correct = np.nonzero(predictions == y_test)[0]
incorrect = np.nonzero(predictions != y_test)[0]

# %%
i = 0
for c in correct[:6]:
    plt.subplot(3,2,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(x_test[c].reshape(150,150), cmap="gray", interpolation='none')
    plt.title("Predicted Class {},Actual Class {}".format(predictions[c], y_test[c]))
    plt.tight_layout()
    i += 1

# %%
i = 0
for c in incorrect[:6]:
    plt.subplot(3,2,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(x_test[c].reshape(150,150), cmap="gray", interpolation='none')
    plt.title("Predicted Class {},Actual Class {}".format(predictions[c], y_test[c]))
    plt.tight_layout()
    i += 1

# %%
history = model.fit(datagen.flow(x_train,y_train, batch_size = 32) ,epochs = 12, validation_data = datagen.flow(x_test,y_test) ,callbacks = [learning_rate_reduction])
# Out:
# Epoch 1/12
# 163/163 [==============================] - 360s 2s/step - loss: 0.2361 - accuracy: 0.9212 - recall: 0.8456 - val_loss: 0.6624 - val_accuracy: 0.6827 - val_recall: 0.1581 - lr: 0.0010
# Epoch 2/12
# 163/163 [==============================] - 350s 2s/step - loss: 0.2217 - accuracy: 0.9325 - recall: 0.8747 - val_loss: 1.2083 - val_accuracy: 0.8157 - val_recall: 0.8162 - lr: 0.0010
# Epoch 3/12
# 163/163 [==============================] - 345s 2s/step - loss: 0.1770 - accuracy: 0.9427 - recall: 0.8941 - val_loss: 0.6248 - val_accuracy: 0.7404 - val_recall: 0.9402 - lr: 0.0010
# Epoch 4/12
# 163/163 [==============================] - 348s 2s/step - loss: 0.1709 - accuracy: 0.9425 - recall: 0.8934 - val_loss: 1.2069 - val_accuracy: 0.8782 - val_recall: 0.7521 - lr: 0.0010
# Epoch 5/12
# 163/163 [==============================] - 348s 2s/step - loss: 0.1583 - accuracy: 0.9423 - recall: 0.8881 - val_loss: 1.2807 - val_accuracy: 0.6394 - val_recall: 0.9786 - lr: 0.0010
# Epoch 6/12
# 163/163 [==============================] - ETA: 0s - loss: 0.1733 - accuracy: 0.9444 - recall: 0.8919
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 163/163 [==============================] - 344s 2s/step - loss: 0.1733 - accuracy: 0.9444 - recall: 0.8919 - val_loss: 0.8686 - val_accuracy: 0.7500 - val_recall: 0.3376 - lr: 0.0010
# Epoch 7/12
# 163/163 [==============================] - 341s 2s/step - loss: 0.1036 - accuracy: 0.9620 - recall: 0.9187 - val_loss: 0.6489 - val_accuracy: 0.8926 - val_recall: 0.7821 - lr: 3.0000e-04
# Epoch 8/12
# 163/163 [==============================] - 339s 2s/step - loss: 0.1171 - accuracy: 0.9615 - recall: 0.9224 - val_loss: 1.5770 - val_accuracy: 0.8478 - val_recall: 0.6197 - lr: 3.0000e-04
# Epoch 9/12
# 163/163 [==============================] - ETA: 0s - loss: 0.1072 - accuracy: 0.9647 - recall: 0.9269
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 163/163 [==============================] - 339s 2s/step - loss: 0.1072 - accuracy: 0.9647 - recall: 0.9269 - val_loss: 2.0522 - val_accuracy: 0.8462 - val_recall: 0.6111 - lr: 3.0000e-04
# Epoch 10/12
# 163/163 [==============================] - 341s 2s/step - loss: 0.0972 - accuracy: 0.9718 - recall: 0.9463 - val_loss: 2.1971 - val_accuracy: 0.7067 - val_recall: 0.2179 - lr: 9.0000e-05
# Epoch 11/12
# 163/163 [==============================] - ETA: 0s - loss: 0.0826 - accuracy: 0.9697 - recall: 0.9389
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 163/163 [==============================] - 339s 2s/step - loss: 0.0826 - accuracy: 0.9697 - recall: 0.9389 - val_loss: 0.4490 - val_accuracy: 0.8878 - val_recall: 0.8248 - lr: 9.0000e-05
# Epoch 12/12
# 163/163 [==============================] - 341s 2s/step - loss: 0.0858 - accuracy: 0.9716 - recall: 0.9478 - val_loss: 0.6472 - val_accuracy: 0.8429 - val_recall: 0.6026 - lr: 2.7000e-05

# %%
print("Loss of the model is - " , model.evaluate(x_test,y_test)[0])
print("Accuracy of the model is - " , model.evaluate(x_test,y_test)[1]*100 , "%")
# Out:
# 20/20 [==============================] - 10s 428ms/step - loss: 0.2566 - accuracy: 0.9151 - recall: 0.8632
# Loss of the model is -  0.2565959393978119
# 20/20 [==============================] - 8s 414ms/step - loss: 0.2566 - accuracy: 0.9151 - recall: 0.8632
# Accuracy of the model is -  91.50640964508057 %

# %%
#same as good score, but with a specific seed

# %%
history = model.fit(datagen.flow(x_train,y_train, batch_size = 32) ,epochs = 12 , validation_data = datagen.flow(x_val, y_val) ,callbacks = [learning_rate_reduction])
# Out:
# Epoch 1/12
# 163/163 [==============================] - 335s 2s/step - loss: 0.5712 - accuracy: 0.8322 - recall_2: 0.6905 - val_loss: 47.3789 - val_accuracy: 0.5000 - val_recall_2: 0.0000e+00 - lr: 0.0010
# Epoch 2/12
# 163/163 [==============================] - 340s 2s/step - loss: 0.2918 - accuracy: 0.8905 - recall_2: 0.8031 - val_loss: 42.5512 - val_accuracy: 0.5000 - val_recall_2: 0.0000e+00 - lr: 0.0010
# Epoch 3/12
# 163/163 [==============================] - ETA: 0s - loss: 0.2518 - accuracy: 0.9116 - recall_2: 0.8337
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 163/163 [==============================] - 335s 2s/step - loss: 0.2518 - accuracy: 0.9116 - recall_2: 0.8337 - val_loss: 40.1927 - val_accuracy: 0.5000 - val_recall_2: 0.0000e+00 - lr: 0.0010
# Epoch 4/12
# 163/163 [==============================] - 331s 2s/step - loss: 0.1579 - accuracy: 0.9444 - recall_2: 0.8986 - val_loss: 0.6918 - val_accuracy: 0.6875 - val_recall_2: 0.5000 - lr: 3.0000e-04
# Epoch 5/12
# 163/163 [==============================] - 338s 2s/step - loss: 0.1453 - accuracy: 0.9480 - recall_2: 0.9016 - val_loss: 15.3994 - val_accuracy: 0.5000 - val_recall_2: 0.0000e+00 - lr: 3.0000e-04
# Epoch 6/12
# 163/163 [==============================] - ETA: 0s - loss: 0.1348 - accuracy: 0.9551 - recall_2: 0.9090
# Epoch 6: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 163/163 [==============================] - 332s 2s/step - loss: 0.1348 - accuracy: 0.9551 - recall_2: 0.9090 - val_loss: 3.6162 - val_accuracy: 0.6250 - val_recall_2: 0.2500 - lr: 3.0000e-04
# Epoch 7/12
# 163/163 [==============================] - 333s 2s/step - loss: 0.1149 - accuracy: 0.9611 - recall_2: 0.9284 - val_loss: 0.2736 - val_accuracy: 0.8750 - val_recall_2: 0.7500 - lr: 9.0000e-05
# Epoch 8/12
# 163/163 [==============================] - 332s 2s/step - loss: 0.1148 - accuracy: 0.9580 - recall_2: 0.9239 - val_loss: 0.7263 - val_accuracy: 0.6250 - val_recall_2: 0.2500 - lr: 9.0000e-05
# Epoch 9/12
# 163/163 [==============================] - ETA: 0s - loss: 0.1027 - accuracy: 0.9659 - recall_2: 0.9321
# Epoch 9: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 163/163 [==============================] - 332s 2s/step - loss: 0.1027 - accuracy: 0.9659 - recall_2: 0.9321 - val_loss: 1.1232 - val_accuracy: 0.6250 - val_recall_2: 0.2500 - lr: 9.0000e-05
# Epoch 10/12
# 163/163 [==============================] - 331s 2s/step - loss: 0.0985 - accuracy: 0.9647 - recall_2: 0.9336 - val_loss: 0.3233 - val_accuracy: 0.8750 - val_recall_2: 0.8750 - lr: 2.7000e-05
# Epoch 11/12
# 163/163 [==============================] - ETA: 0s - loss: 0.0914 - accuracy: 0.9668 - recall_2: 0.9359
# Epoch 11: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 163/163 [==============================] - 333s 2s/step - loss: 0.0914 - accuracy: 0.9668 - recall_2: 0.9359 - val_loss: 0.9139 - val_accuracy: 0.6875 - val_recall_2: 0.3750 - lr: 2.7000e-05
# Epoch 12/12
# 163/163 [==============================] - 331s 2s/step - loss: 0.0955 - accuracy: 0.9670 - recall_2: 0.9463 - val_loss: 0.9825 - val_accuracy: 0.6250 - val_recall_2: 0.2500 - lr: 8.1000e-06

# %%
print("Loss of the model is - " , model.evaluate(x_test,y_test)[0])
print("Accuracy of the model is - " , model.evaluate(x_test,y_test)[1]*100 , "%")
# Out:
# 20/20 [==============================] - 9s 420ms/step - loss: 0.3176 - accuracy: 0.9135 - recall_2: 0.8803
# Loss of the model is -  0.31758517026901245
# 20/20 [==============================] - 8s 415ms/step - loss: 0.3176 - accuracy: 0.9135 - recall_2: 0.8803
# Accuracy of the model is -  91.34615659713745 %

# %%
from keras import regularizers

# %%
#andys 
model = Sequential()

model.add(Conv2D(filters=16, kernel_size=3, kernel_regularizer = regularizers.l2(.01),  activation='relu', input_shape=(150,150,1)))
model.add(MaxPool2D(pool_size=2, strides=2))


model.add(Conv2D(filters=32, kernel_size=3, kernel_regularizer = regularizers.l2(.01), activation='relu'))
model.add(MaxPool2D(pool_size=2, strides=2))


model.add(Conv2D(filters=64, kernel_size=3, kernel_regularizer = regularizers.l2(.01), activation='relu'))
model.add(MaxPool2D(pool_size=2, strides=2))

model.add(Conv2D(filters=64, kernel_size=3, kernel_regularizer = regularizers.l2(.01), activation='relu'))
model.add(MaxPool2D(pool_size=2, strides=2))


model.add(Flatten())
model.add(Dense(units=128, kernel_regularizer = regularizers.l2(.01), activation='relu'))
model.add(Dense(units=1, kernel_regularizer = regularizers.l2(.01), activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 148, 148, 16)      160
#
#  max_pooling2d_5 (MaxPooling  (None, 74, 74, 16)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 72, 72, 32)        4640
#
#  max_pooling2d_6 (MaxPooling  (None, 36, 36, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 34, 34, 64)        18496
#
#  max_pooling2d_7 (MaxPooling  (None, 17, 17, 64)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 15, 15, 64)        36928
#
#  max_pooling2d_8 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 3136)              0
#
#  dense_2 (Dense)             (None, 128)               401536
#
#  dense_3 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 461,889
# Trainable params: 461,889
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras import callbacks

# %%
earlystopping = callbacks.EarlyStopping(monitor ="val_loss", 
                                        mode ="min", patience = 5, 
                                        restore_best_weights = True)

# %%
model.compile(optimizer = tf.keras.optimizers.Adam(),
             loss = tf.keras.losses.BinaryCrossentropy(),
              metrics = ['accuracy',tf.keras.metrics.Recall()])

# %%
history = model.fit(datagen.flow(x_train,y_train, batch_size = 32) ,epochs = 12 , validation_data = datagen.flow(x_val, y_val) ,callbacks = earlystopping)
# Out:
# Epoch 1/12
# 163/163 [==============================] - 108s 653ms/step - loss: 1.0936 - accuracy: 0.7379 - recall_1: 0.0022 - val_loss: 0.9616 - val_accuracy: 0.5000 - val_recall_1: 0.0000e+00
# Epoch 2/12
# 163/163 [==============================] - 104s 638ms/step - loss: 0.6128 - accuracy: 0.7429 - recall_1: 0.0000e+00 - val_loss: 0.8454 - val_accuracy: 0.5000 - val_recall_1: 0.0000e+00
# Epoch 3/12
# 163/163 [==============================] - 105s 641ms/step - loss: 0.5657 - accuracy: 0.7582 - recall_1: 0.1119 - val_loss: 0.8038 - val_accuracy: 0.6250 - val_recall_1: 0.2500
# Epoch 4/12
# 163/163 [==============================] - 103s 629ms/step - loss: 0.4809 - accuracy: 0.8171 - recall_1: 0.4713 - val_loss: 0.9859 - val_accuracy: 0.6250 - val_recall_1: 0.2500
# Epoch 5/12
# 163/163 [==============================] - 101s 619ms/step - loss: 0.4575 - accuracy: 0.8317 - recall_1: 0.5265 - val_loss: 1.5290 - val_accuracy: 0.5000 - val_recall_1: 0.1250
# Epoch 6/12
# 163/163 [==============================] - 102s 628ms/step - loss: 0.4336 - accuracy: 0.8468 - recall_1: 0.6055 - val_loss: 0.8454 - val_accuracy: 0.6250 - val_recall_1: 0.3750
# Epoch 7/12
# 163/163 [==============================] - 101s 617ms/step - loss: 0.4235 - accuracy: 0.8574 - recall_1: 0.6294 - val_loss: 0.8304 - val_accuracy: 0.6875 - val_recall_1: 0.6250
# Epoch 8/12
# 163/163 [==============================] - 109s 667ms/step - loss: 0.4470 - accuracy: 0.8418 - recall_1: 0.5735 - val_loss: 1.2009 - val_accuracy: 0.4375 - val_recall_1: 0.1250

# %%
from sklearn.metrics import plot_confusion_matrix, accuracy_score, confusion_matrix, plot_roc_curve, \
make_scorer, recall_score, precision_score, f1_score

# %%
# #recall score
# predict_x=model.predict(x) 
# classes_x=np.argmax(predict_x,axis=1)

# #yhat_classes = classes_x[:, 0]
# recall_score(y_test, classes_x)

# %%
# print(f"Training Score of first convolution neural network: {model.evaluate(x_train, y_train)}")
# print(f"Test Score of first convolution neural network: {model.evaluate(x_test, y_test)}")

# %%
# history = model.fit(datagen.flow(x_train,y_train, batch_size = 28), steps_per_epoch = 50, epochs = 12 , validation_data = datagen.flow(x_val, y_val) ,callbacks = [learning_rate_reduction])
# Out:
# Epoch 1/12
# 50/50 [==============================] - 90s 2s/step - loss: 0.8844 - accuracy: 0.7864 - val_loss: 0.6437 - val_accuracy: 0.6250 - lr: 0.0010
# Epoch 2/12
# 50/50 [==============================] - 88s 2s/step - loss: 0.4624 - accuracy: 0.8312 - val_loss: 0.7335 - val_accuracy: 0.5625 - lr: 0.0010
# Epoch 3/12
# 50/50 [==============================] - 88s 2s/step - loss: 0.4280 - accuracy: 0.8529 - val_loss: 0.2660 - val_accuracy: 0.9375 - lr: 0.0010
# Epoch 4/12
# 50/50 [==============================] - 88s 2s/step - loss: 0.3257 - accuracy: 0.8746 - val_loss: 1.5932 - val_accuracy: 0.6250 - lr: 0.0010
# Epoch 5/12
# 50/50 [==============================] - ETA: 0s - loss: 0.3391 - accuracy: 0.8779
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 50/50 [==============================] - 87s 2s/step - loss: 0.3391 - accuracy: 0.8779 - val_loss: 1.1313 - val_accuracy: 0.4375 - lr: 0.0010
# Epoch 6/12
# 50/50 [==============================] - 86s 2s/step - loss: 0.2475 - accuracy: 0.9072 - val_loss: 0.8089 - val_accuracy: 0.7500 - lr: 3.0000e-04
# Epoch 7/12
# 50/50 [==============================] - ETA: 0s - loss: 0.1923 - accuracy: 0.9321
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0001.
# 50/50 [==============================] - 89s 2s/step - loss: 0.1923 - accuracy: 0.9321 - val_loss: 1.8900 - val_accuracy: 0.5000 - lr: 3.0000e-04
# Epoch 8/12
# 50/50 [==============================] - 87s 2s/step - loss: 0.1893 - accuracy: 0.9357 - val_loss: 2.8181 - val_accuracy: 0.5000 - lr: 1.0000e-04
# Epoch 9/12
# 50/50 [==============================] - 86s 2s/step - loss: 0.1864 - accuracy: 0.9297 - val_loss: 2.6798 - val_accuracy: 0.5625 - lr: 1.0000e-04
# Epoch 10/12
# 50/50 [==============================] - 87s 2s/step - loss: 0.1491 - accuracy: 0.9486 - val_loss: 0.7093 - val_accuracy: 0.7500 - lr: 1.0000e-04
# Epoch 11/12
# 50/50 [==============================] - 87s 2s/step - loss: 0.1771 - accuracy: 0.9379 - val_loss: 5.1768 - val_accuracy: 0.5000 - lr: 1.0000e-04
# Epoch 12/12
# 50/50 [==============================] - 89s 2s/step - loss: 0.1737 - accuracy: 0.9350 - val_loss: 1.9780 - val_accuracy: 0.5000 - lr: 1.0000e-04

# %%
from sklearn.metrics import plot_confusion_matrix, accuracy_score, confusion_matrix, plot_roc_curve, \
make_scorer, recall_score, precision_score, f1_score

# %%
#recall score
predict_x=model.predict(x_test) 
classes_x=np.argmax(predict_x,axis=1)

#yhat_classes = classes_x[:, 0]
recall_score(y_test, classes_x)
# Out:
# 0.0

# %%
#recall score
predict_x=model.predict(x_test) 
classes_x=np.argmax(predict_x,axis=1)

#yhat_classes = classes_x[:, 0]
recall_score(y_test, classes_x)
# Out:
# 0.0
